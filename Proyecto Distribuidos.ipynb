# %%
import matplotlib as pyplot

# %%
import pandas as pd

# %%
results = pd.read_csv('results.csv')
results.head()
# Out:
#        timeStamp  elapsed         label  responseCode responseMessage  \
# 0  1598362822022        8  HTTP Request           200              OK
# 1  1598362822044        8  HTTP Request           200              OK
# 2  1598362822062        8  HTTP Request           200              OK
# 3  1598362822081        9  HTTP Request           200              OK
# 4  1598362822101        8  HTTP Request           200              OK
#
#          threadName dataType  success  failureMessage  bytes  sentBytes  \
# 0  Thread Group 1-1     text     True             NaN   5248        116
# 1  Thread Group 1-2     text     True             NaN   5248        116
# 2  Thread Group 1-3     text     True             NaN   5248        116
# 3  Thread Group 1-4     text     True             NaN   5248        116
# 4  Thread Group 1-5     text     True             NaN   5248        116
#
#    grpThreads  allThreads                     URL  Latency  IdleTime  Connect
# ...

# %%
boxplot = results.boxplot(column=['Latency'])

# %%
boxplot = results.boxplot(column=['IdleTime'])#'elapsed'

# %%
boxplot = results.boxplot(column=['elapsed'])

# %%
results.describe()
# Out:
#           timeStamp    elapsed  responseCode  failureMessage   bytes  \
# count  5.000000e+02  500.00000         500.0             0.0   500.0
# mean   1.598363e+12    7.50800         200.0             NaN  5248.0
# std    2.889829e+03    3.59831           0.0             NaN     0.0
# min    1.598363e+12    5.00000         200.0             NaN  5248.0
# 25%    1.598363e+12    6.00000         200.0             NaN  5248.0
# 50%    1.598363e+12    7.00000         200.0             NaN  5248.0
# 75%    1.598363e+12    7.00000         200.0             NaN  5248.0
# max    1.598363e+12   35.00000         200.0             NaN  5248.0
#
#        sentBytes  grpThreads  allThreads     Latency  IdleTime     Connect
# count      500.0  500.000000  500.000000  500.000000     500.0  500.000000
# mean       116.0    1.030000    1.030000    7.476000       0.0    0.452000
# std          0.0    0.170758    0.170758    3.589316       0.0    0.724393
# ...

# %%
df = results[['timeStamp', 'elapsed', 'Latency', 'IdleTime']].copy()

# %%
results.plot(figsize=(15,4))
results.plot(subplots=True, figsize=(15,6))
results.plot(x="timeStamp", y=["elapsed"], figsize=(15,6))

# %%
df.head()
# Out:
#        timeStamp  elapsed  Latency  IdleTime
# 0  1598362822022        8        8         0
# 1  1598362822044        8        8         0
# 2  1598362822062        8        8         0
# 3  1598362822081        9        9         0
# 4  1598362822101        8        8         0

# %%
df = df.set_index('timeStamp')

# %%
df.plot(figsize=(15,4))
df.plot(subplots=True, figsize=(15,6))
#df.plot(x="timeStamp", y=["elapsed"], figsize=(15,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f10e847c748>,
# ...
#       dtype=object)

# %%
# Out:
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# <ipython-input-24-9e10b8c312c2> in <module>
#      12 # Parse the CSV files
#      13 for file in sys.argv[1:]:
# ---> 14   threads = int(file.split('-')[0])
#      15   for row in csv.DictReader(open(file)):
#      16     if (not row['label'] in elapsed):
#
# ValueError: invalid literal for int() with base 10: ''
